# %%
import numpy as np

# (8 models x 6 preprocessing x 6 outputs) RMSE values
# order: PLS, SVM, KNN, DT, RF, VOTE, STACK, XGB
# preprocessing: S, SL, N, NL, NM, NML
# outputs: T, H2O, CO2, CH4, CO, NH3

rmse = np.array([
    # PLS
    [[515.836, 2.355, 1.824, 2.399, 1.211, 1.853],
     [515.836, 1.386, 1.1747, 1.367, 0.727, 1.156],
     [199.181, 2.204, 1.556, 2.270, 1.578, 1.694],
     [199.181, 0.729, 0.449, 0.407, 0.468, 0.652],
     [198.297, 2.188, 1.561, 2.261, 1.584, 1.693],
     [198.297, 0.728, 0.448, 0.407, 0.467, 0.652]],
    # SVM
    [[430.293, 1.758, 1.348, 1.872, 0.807, 1.408],
     [430.293, 1.292, 1.014, 1.100, 0.806, 1.111],
     [110.257, 1.938, 1.538, 1.813, 1.821, 1.258],
     [110.257, 0.363, 0.131, 0.251, 0.218, 0.439],
     [110.246, 1.938, 1.538, 1.815, 1.821, 1.259],
     [110.246, 0.363, 0.131, 0.251, 0.218, 0.439]],
    # KNN
    [[380.519, 1.661, 1.432, 0.973, 1.042, 1.385],
     [380.519, 1.202, 1.063, 0.749, 0.885, 1.061],
     [151.373, 0.718, 0.4646, 0.400, 0.648, 0.7099],
     [151.373, 0.592, 0.370, 0.357, 0.528, 0.616],
     [155.210, 0.739, 0.3245, 0.409, 0.576, 0.724],
     [155.210, 0.609, 0.278, 0.369, 0.477, 0.628]],
    # DT
    [[504.911, 2.151, 1.736, 1.827, 1.0547, 1.733],
     [516.498, 1.521, 1.199, 1.103, 0.866, 1.289],
     [270.947, 1.226, 1.134, 0.8546, 0.803, 1.121],
     [281.982, 0.817, 0.631, 0.596, 0.626, 0.759],
     [266.802, 1.217, 1.144, 0.865, 0.787, 1.107],
     [289.964, 0.805, 0.651, 0.582, 0.641, 0.779]],
    # RF
    [[442.380, 2.313, 1.818, 2.099, 1.048, 1.812],
     [464.273, 1.376, 0.976, 0.933, 0.823, 1.173],
     [181.419, 1.511, 1.286, 1.141, 0.769, 1.250],
     [189.856, 0.635, 0.398, 0.469, 0.4595, 0.612],
     [179.734, 1.504, 1.284, 1.143, 0.772, 1.253],
     [189.174, 0.635, 0.396, 0.470, 0.461, 0.613]],
    # VOTE
    [[380.307, 1.886, 1.489, 1.653, 0.962, 1.547],
     [380.307, 1.112, 0.849, 0.757, 0.777, 0.990],
     [131.806, 1.413, 0.972, 1.338, 0.674, 0.925],
     [131.806, 0.440, 0.224, 0.271, 0.333, 0.481],
     [131.713, 1.416, 0.960, 1.342, 0.718, 0.931],
     [131.713, 0.446, 0.189, 0.277, 0.327, 0.487]],
    # STACK
    [[377.015, 1.071, 0.837, 0.904, 0.751, 0.968],
     [377.015, 0.959, 0.707, 0.755, 0.754, 0.922],
     [100.196, 0.665, 0.337, 0.381, 0.296, 0.663],
     [100.196, 0.368, 0.138, 0.267, 0.220, 0.463],
     [94.764,  0.681, 0.284, 0.388, 0.292, 0.661],
     [94.764,  0.371, 0.139, 0.270, 0.218, 0.457]],
    # XGB
    [[379.333, 2.018, 1.5298, 1.904, 1.028, 1.642],
     [379.333, 1.125, 0.772, 0.789, 0.742, 1.023],
     [114.413, 1.266, 1.212, 1.179, 1.784, 0.937],
     [114.413, 0.386, 0.166, 0.253, 0.248, 0.436],
     [117.821, 1.276, 1.193, 1.190, 1.776, 0.933],
     [117.821, 0.3899, 0.167, 0.251, 0.246, 0.437]],
])  # shape: (8, 6, 6)

# (8 models x 6 preprocessing) cost values
cost = np.array([
    [2.276,     2.632,      3.028,      2.6296,     4.384,      3.247  ],  # PLS
    [493.848,   691.740,    282.502,    334.035,    297.094,    355.203  ],  # SVM
    [1.809,     2.011,      6.84,       6.490,      8.718,      8.906 ],  # KNN
    [0.139,     0.122,      0.123,      0.109,      0.113,      0.111  ],  # DT
    [156.034 ,  147.407,    102.787,    83.161,     103.1747,   85.311],  # RF
    [2024.790,  2448.533,   977.864,    892.563,    998.627,    911.123 ],  # VOTE
    [1756.056,  2276.298,   1071.888,   1293.367,   1171.241,   1294.5449 ],  # STACK
    [2.379,     2.388,      2.353,      2.828,      2.529,      2.583],  # XGB
])  # shape: (8, 6)

# expand cost to (8, 6, 1) and concatenate → (8, 6, 7)
cost_expanded = cost[:, :, np.newaxis]
tensor = np.concatenate([rmse, cost_expanded], axis=2)  # (8, 6, 7)

# standardize per feature across all (model, preprocessing) combinations
# mean and std computed over axes 0 and 1, shape (7,)
mean = tensor.mean(axis=(0, 1))   # (7,)
std  = tensor.std(axis=(0, 1))    # (7,)

tensor_standardized = (tensor - mean) / std  # (8, 6, 7)

# composite score: (-1) * mean across all 7 standardized features
# shape (8, 6) — one score per model/preprocessing combination
score = -1 * tensor_standardized.mean(axis=2)  # (8, 6)

# print as a table
models = ['PLS', 'SVM', 'KNN', 'DT', 'RF', 'VOTE', 'STACK', 'XGB']
schemes = ['S', 'SL', 'N', 'NL', 'NM', 'NML']

print(f"{'Model':<8}", "  ".join(f"{s:>8}" for s in schemes))
print("-" * 65)
for i, model in enumerate(models):
    print(f"{model:<8}", "  ".join(f"{score[i,j]:>8.3f}" for j in range(6)))
# Out:
# Model           S        SL         N        NL        NM       NML
# -----------------------------------------------------------------
# PLS        -1.499    -0.459    -1.099     0.696    -1.096     0.697
# SVM        -0.842    -0.406    -0.824     1.078    -0.828     1.074
# KNN        -0.548    -0.124     0.665     0.803     0.710     0.828
# DT         -1.193    -0.530    -0.054     0.410    -0.043     0.390
# RF         -1.311    -0.321    -0.193     0.727    -0.191     0.726
# VOTE       -1.244    -0.523    -0.125     0.834    -0.145     0.837
# STACK      -0.372    -0.375     0.667     0.863     0.661     0.869
# XGB        -0.954     0.024    -0.251     1.123    -0.250     1.119
